# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonryu/Machine-Learning/blob/main/C%C3%B3pia_de_Curso_de_Open_CV_Puthon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ######OpenCv

# %% [markdown]
# >Carregamento de Imagem

# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
imagem = cv2.imread('/content/drive/MyDrive/fotos/20180114_020636.jpg')

# %%
imagem.shape
# Out:
# (1600, 1200, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x1600 at 0x7F3006BE1C90>

# %% [markdown]
# >>>diminuir o tamanho da imagem para o processamento ser mais rapido

# %%
imagem = cv2.resize(imagem, (400,300))
imagem.shape
# Out:
# (300, 400, 3)

# %%
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F3006BD3390>

# %%
ImagemCinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
cv2_imshow(ImagemCinza)
# Out:
# <PIL.Image.Image image mode=L size=400x300 at 0x7F3006BE6750>

# %%
ImagemCinza.shape
# Out:
# (300, 400)

# %% [markdown]
# >Detecção de faces

# %% [markdown]
# >Parâmetro Haarcascade

# %% [markdown]
# >Detecção de olhos

# %% [markdown]
# ###Outros objetos
